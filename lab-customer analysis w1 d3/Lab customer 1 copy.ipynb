# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# #Read the three files into python as dataframes

# %% [markdown]
# # Importing all the csv files

# %%
file1 = pd.read_csv ('file1_1.csv')

# %%
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file2 = pd.read_csv ('file2_1.csv')

# %%
file2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
file3 = pd.read_csv ('file3_1.csv')

# %%
file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %% [markdown]
# # Show the DataFrame's shape

# %%
file1.shape
# Out:
# (4008, 11)

# %%
file2.shape
# Out:
# (996, 11)

# %%
file3.shape
# Out:
# (7070, 11)

# %% [markdown]
# # Standardize header names & Rearrange the columns in the dataframe as needed

# %%
# different steps, first set all the attributes to small letters, then adjust attributes as needed to coincide with 
# the other data sets.

# %% [markdown]
# # Setting all the attributes to small letters

# %%
columns1 = []  # creating a list of the attributes, converting them to lower case letters
for i in range(len(file1.columns)):
    columns1.append (file1.columns[i].lower())

# %%
file1.columns = columns1 # replace the original CAPS attributes to lower case by overwriting it with the 
                           #created list

# %%
file1.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
columns2 = []  # creating a list of the attributes, converting them to lower case letters
for i in range(len(file2.columns)):
    columns2.append (file2.columns[i].lower())

# %%
file2.columns = columns2 # replace the original CAPS attributes to lower case by overwriting it with the 
                           #created list

# %%
file2.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'total claim amount', 'policy type', 'vehicle class'],
#       dtype='object')

# %%
columns3 = []  # creating a list of the attributes, converting them to lower case letters
for i in range(len(file3.columns)):
    columns3.append (file3.columns[i].lower())

# %%
file3.columns = columns3 # replace the original CAPS attributes to lower case by overwriting it with the 
                           #created list

# %%
file3.columns
# Out:
# Index(['customer', 'state', 'customer lifetime value', 'education', 'gender',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'total claim amount', 'vehicle class'],
#       dtype='object')

# %%
file1.head(2)
# Out:
#   customer          st gender education customer lifetime value  income  \
# 0  RB50392  Washington    NaN    Master                     NaN     0.0
# 1  QZ44356     Arizona      F  Bachelor              697953.59%     0.0
#
#    monthly premium auto number of open complaints    policy type  \
# 0                1000.0                    1/0/00  Personal Auto
# 1                  94.0                    1/0/00  Personal Auto
#
#    vehicle class  total claim amount
# 0  Four-Door Car            2.704934
# 1  Four-Door Car         1131.464935

# %%
file2.head(2)
# Out:
#   customer          st gender education customer lifetime value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
#
#    monthly premium auto number of open complaints  total claim amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
#
#      policy type  vehicle class
# 0  Personal Auto  Four-Door Car
# 1   Special Auto            SUV

# %%
file3.head(2)
# Out:
#   customer       state  customer lifetime value             education gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
#
#    income  monthly premium auto  number of open complaints    policy type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
#
#    total claim amount vehicle class
# 0          499.200000  Two-Door Car
# 1            3.468912  Two-Door Car

# %%
file3_names = {"state": "st"} # change the name of the column for better understanding /coincide with the other set
                              # here you state what you want the change to be by using a dictionary

# %%
file3.rename (columns = file3_names, inplace = True) # here you actually change the name of the column 
                                                     #for better understanding

# %%
file3.head(2) # now all names are the same
# Out:
#   customer          st  customer lifetime value             education gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
#
#    income  monthly premium auto  number of open complaints    policy type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
#
#    total claim amount vehicle class
# 0          499.200000  Two-Door Car
# 1            3.468912  Two-Door Car

# %% [markdown]
# # Concatenate the three dataframes

# %%
file_complete=pd.concat([file1,file2,file3]) # here you join the 3 files together

# %%
file_complete.shape # checking if the shape of the complete file makes sense
# Out:
# (12074, 11)

# %%
file_complete.head(2) # now all names are the same
# Out:
#   customer          st gender education customer lifetime value  income  \
# 0  RB50392  Washington    NaN    Master                     NaN     0.0
# 1  QZ44356     Arizona      F  Bachelor              697953.59%     0.0
#
#    monthly premium auto number of open complaints    policy type  \
# 0                1000.0                    1/0/00  Personal Auto
# 1                  94.0                    1/0/00  Personal Auto
#
#    vehicle class  total claim amount
# 0  Four-Door Car            2.704934
# 1  Four-Door Car         1131.464935

# %% [markdown]
# # Which columns are numerical & Which columns are categorical?

# %%
file_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9134 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9134 non-null   object
#  1   st                         9134 non-null   object
#  2   gender                     9012 non-null   object
#  3   education                  9134 non-null   object
#  4   customer lifetime value    9127 non-null   object
#  5   income                     9134 non-null   float64
#  6   monthly premium auto       9134 non-null   float64
#  7   number of open complaints  9134 non-null   object
#  8   policy type                9134 non-null   object
#  9   vehicle class              9134 non-null   object
#  10  total claim amount         9134 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 856.3+ KB

# %% [markdown]
# # Understand the meaning of all columns

# %%
# not sure what the meaning is of this question, i think the attributes are quite clear?

# %% [markdown]
# # Delete the column education and the number of open complaints from the dataframe.

# %%
file_complete1 = file_complete.drop(["education", "number of open complaints"], axis = 1) 
# if you want to delete columns axis = 1
# if you want to delete a row axis = 0

# %%
file_complete1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9134 entries, 0 to 7069
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer                 9134 non-null   object
#  1   st                       9134 non-null   object
#  2   gender                   9012 non-null   object
#  3   customer lifetime value  9127 non-null   object
#  4   income                   9134 non-null   float64
#  5   monthly premium auto     9134 non-null   float64
#  6   policy type              9134 non-null   object
#  7   vehicle class            9134 non-null   object
#  8   total claim amount       9134 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 713.6+ KB

# %% [markdown]
# # Correct the values in the column customer lifetime value.
# ## They are given as a percent, so multiply them by 100 and change dtype to numerical type.

# %% [markdown]
# # Check for duplicate rows in the data and remove if any.

# %%
file_complete.duplicated().sum()
# Out:
# 2939

# %%
file_complete['customer'].value_counts()
# Out:
# QD28391    2
# YB66933    2
# LY14355    2
# FX36546    2
# OT85112    2
#           ..
# KG49115    1
# NT78297    1
# TN66124    1
# JV99867    1
# Y167826    1
# Name: customer, Length: 9056, dtype: int64

# %%
file_complete=file_complete.dropna(subset = ['customer'])

# %%
file_complete=file_complete.drop_duplicates()

# %%
file_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9134 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9134 non-null   object
#  1   st                         9134 non-null   object
#  2   gender                     9012 non-null   object
#  3   education                  9134 non-null   object
#  4   customer lifetime value    9127 non-null   object
#  5   income                     9134 non-null   float64
#  6   monthly premium auto       9134 non-null   float64
#  7   number of open complaints  9134 non-null   object
#  8   policy type                9134 non-null   object
#  9   vehicle class              9134 non-null   object
#  10  total claim amount         9134 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 856.3+ KB

# %% [markdown]
# # Filter out the data for customers who have an income of 0 or less.

# %%
file_complete.query('income <= 0') # query filtering out whatever needed
# here all customers that have an income of 0 or less
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 7     CF85061     Arizona      M                Master
# 10    SX51350  California      M               College
# ...       ...         ...    ...                   ...
# 7059  WZ45103  California      F              Bachelor
# 7061  RX91025  California      M  High School or Below
# 7062  AC13887  California      M              Bachelor
# 7067  TD14365  California      M              Bachelor
# 7069  Y167826  California      M               College
#
#      customer lifetime value  income  monthly premium auto  \
# 0                        NaN     0.0                1000.0
# 1                 697953.59%     0.0                  94.0
# 3                 764586.18%     0.0                 106.0
# 7                 721610.03%     0.0                 101.0
# ...
