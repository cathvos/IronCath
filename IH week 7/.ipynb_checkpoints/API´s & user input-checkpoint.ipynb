# %% [markdown]
# # 1. User input

# %%
entered_value=input('enter some value: ')
# Out:
# enter some value: hi

# %%
entered_value
# Out:
# 'hi'

# %%
name=input('enter your name ').lstrip().rstrip().lower()
shoe_size=int(input('enter your shoe size '))
# Out:
# enter your name    CAth
# enter your shoe size 37

# %%
name
# Out:
# 'cath'

# %% [markdown]
# # 1.1 exception handling

# %%
try:
    shoe_size=int(input('enter your shoe size in whole numbers: '))
    print('great job, thats a shoesize. the number is ',shoe_size)

except ValueError:
    print('this is not a whole number, try again....')
# Out:
# enter your shoe size in whole numbers: 40
# great job, thats a shoesize. the number is  40

# %%
if len(input('enter a song... ')) < 2:
    print('input to short, please try again')
# Out:
# enter a song... hdsg

# %% [markdown]
# # 1.2 is this in a list of values

# %%
guest_list=['sian', 'andy', 'miguel', 'roger']

# %%
yourname=input('tell me your name please ')
# Out:
# tell me your name please Cath

# %%
if yourname in guest_list:
    print('welcome you are on the guest list, get a free cocktail ')
else:
    print ('your name is not down and youre not coming in')
# Out:
# your name is not down and youre not coming in

# %% [markdown]
# # 2. APIs

# %%
import requests
import json

# %%
google = requests.get('https://developers.google.com')
print('Google:', google.status_code)
NBA = requests.get('https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason')
print('NBA:', NBA.status_code)
rotten_tomato = requests.get('http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json')
print('Rotten Tomatoes:', rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# # 2.1 GitHub API

# %%
github_response=requests.get('https://api.github.com/users/cathvos/events/public')
github_response.status_code
# Out:
# 200

# %%
github_response.json()
# Out:
# [{'id': '21957645509',
#   'type': 'PushEvent',
#   'actor': {'id': 101712996,
#    'login': 'cathvos',
#    'display_login': 'cathvos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cathvos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?'},
#   'repo': {'id': 480380113,
#    'name': 'cathvos/IronCath',
#    'url': 'https://api.github.com/repos/cathvos/IronCath'},
#   'payload': {'push_id': 9969208504,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/main',
#    'head': '99fabd83ffd77cd098e973717f244df6ffcf2fa4',
#    'before': '42bc28fa7f72541762967e4ddc4690f9287f0636',
#    'commits': [{'sha': 'c9155dad815df5fc073bf231615f9ee6f7ea52ee',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'labs',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/IronCath/commits/c9155dad815df5fc073bf231615f9ee6f7ea52ee'},
#     {'sha': 'a5abf5f8b7d78d643908a3f264ca123ef79135cc',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'labs',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/IronCath/commits/a5abf5f8b7d78d643908a3f264ca123ef79135cc'},
#     {'sha': '99fabd83ffd77cd098e973717f244df6ffcf2fa4',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': "Merge branch 'main' of https://github.com/cathvos/IronCath",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/IronCath/commits/99fabd83ffd77cd098e973717f244df6ffcf2fa4'}]},
#   'public': True,
#   'created_at': '2022-05-24T13:26:14Z'},
#  {'id': '21850820150',
#   'type': 'PushEvent',
#   'actor': {'id': 101712996,
#    'login': 'cathvos',
#    'display_login': 'cathvos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cathvos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?'},
#   'repo': {'id': 480380113,
#    'name': 'cathvos/IronCath',
#    'url': 'https://api.github.com/repos/cathvos/IronCath'},
#   'payload': {'push_id': 9914584890,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '42bc28fa7f72541762967e4ddc4690f9287f0636',
#    'before': 'b823b92b558c7b770b2563079ea4afc74d609143',
#    'commits': [{'sha': '42bc28fa7f72541762967e4ddc4690f9287f0636',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'Create lab 1, day 3,README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/IronCath/commits/42bc28fa7f72541762967e4ddc4690f9287f0636'}]},
#   'public': True,
#   'created_at': '2022-05-18T09:44:42Z'},
#  {'id': '21831572049',
#   'type': 'PushEvent',
#   'actor': {'id': 101712996,
#    'login': 'cathvos',
#    'display_login': 'cathvos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cathvos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?'},
#   'repo': {'id': 480380113,
#    'name': 'cathvos/IronCath',
#    'url': 'https://api.github.com/repos/cathvos/IronCath'},
#   'payload': {'push_id': 9904934180,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b823b92b558c7b770b2563079ea4afc74d609143',
#    'before': 'ae955f0cbac9b942add99503aaec3dc7dad9d984',
#    'commits': [{'sha': 'b823b92b558c7b770b2563079ea4afc74d609143',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/IronCath/commits/b823b92b558c7b770b2563079ea4afc74d609143'}]},
#   'public': True,
#   'created_at': '2022-05-17T12:44:36Z'},
#  {'id': '21831141340',
#   'type': 'PushEvent',
#   'actor': {'id': 101712996,
#    'login': 'cathvos',
#    'display_login': 'cathvos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cathvos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?'},
#   'repo': {'id': 480380113,
#    'name': 'cathvos/IronCath',
#    'url': 'https://api.github.com/repos/cathvos/IronCath'},
#   'payload': {'push_id': 9904722361,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ae955f0cbac9b942add99503aaec3dc7dad9d984',
#    'before': '668dab8ced38c4c28424b498d443600634a73610',
#    'commits': [{'sha': 'ae955f0cbac9b942add99503aaec3dc7dad9d984',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'labs',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/IronCath/commits/ae955f0cbac9b942add99503aaec3dc7dad9d984'}]},
#   'public': True,
#   'created_at': '2022-05-17T12:23:42Z'},
#  {'id': '21807952642',
#   'type': 'PushEvent',
#   'actor': {'id': 101712996,
#    'login': 'cathvos',
#    'display_login': 'cathvos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cathvos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?'},
#   'repo': {'id': 481923883,
#    'name': 'cathvos/BCNDATA2022',
#    'url': 'https://api.github.com/repos/cathvos/BCNDATA2022'},
#   'payload': {'push_id': 9893504582,
#    'size': 8,
#    'distinct_size': 8,
#    'ref': 'refs/heads/main',
#    'head': 'fd35099aaa6bc1913262e6be3d91a61277d21b94',
#    'before': 'c5e207df710d3b445b48df4757608fc6d04af00c',
#    'commits': [{'sha': 'ea807f74bbd67bb865856e837b960bc9f5c5236c',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Create fri_6_may.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/BCNDATA2022/commits/ea807f74bbd67bb865856e837b960bc9f5c5236c'},
#     {'sha': '79bc6bc74ce60383260e639e59c10c1a89aaddd2',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Create abTesting.xlsx',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/BCNDATA2022/commits/79bc6bc74ce60383260e639e59c10c1a89aaddd2'},
#     {'sha': 'bfabaab502edb4f67e696edebade1b7e48875d6c',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'move around data for week 6 classes',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/BCNDATA2022/commits/bfabaab502edb4f67e696edebade1b7e48875d6c'},
#     {'sha': 'd860d12fe393274daae88bbafbfeee404204bec5',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'update data sources week 6',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/BCNDATA2022/commits/d860d12fe393274daae88bbafbfeee404204bec5'},
#     {'sha': 'fec9142fb2f13c7cfe5c5e7d2445a59d939dc63d',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Databricks_intro.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/BCNDATA2022/commits/fec9142fb2f13c7cfe5c5e7d2445a59d939dc63d'},
#     {'sha': '15e27b2ecb73df710a567f34dd3c2ba715600dc8',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'update case study',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/BCNDATA2022/commits/15e27b2ecb73df710a567f34dd3c2ba715600dc8'},
#     {'sha': 'af3fb301741793d1d481f1f6a91213c72c678dde',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Create stats_16_May_22.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/BCNDATA2022/commits/af3fb301741793d1d481f1f6a91213c72c678dde'},
#     {'sha': 'fd35099aaa6bc1913262e6be3d91a61277d21b94',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Create readme.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/BCNDATA2022/commits/fd35099aaa6bc1913262e6be3d91a61277d21b94'}]},
#   'public': True,
#   'created_at': '2022-05-16T12:10:21Z'},
#  {'id': '21760867394',
#   'type': 'PushEvent',
#   'actor': {'id': 101712996,
#    'login': 'cathvos',
#    'display_login': 'cathvos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cathvos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?'},
#   'repo': {'id': 490211118,
#    'name': 'federicariva/MidbootcampProject',
#    'url': 'https://api.github.com/repos/federicariva/MidbootcampProject'},
#   'payload': {'push_id': 9867799745,
#    'size': 26,
#    'distinct_size': 26,
#    'ref': 'refs/heads/main',
#    'head': '2f76f83df73eee6be05baaabb84c081ca730e035',
#    'before': 'f218bffa51c9321d66403a4a4d33f76ae2fcd98d',
#    'commits': [{'sha': 'd153029ca1a5aa63b0dc53850e9096bd1d0afe67',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'project',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/federicariva/MidbootcampProject/commits/d153029ca1a5aa63b0dc53850e9096bd1d0afe67'},
#     {'sha': 'c7acb872835aea6b7c67322c72dfcbdeafe61a5d',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': "Merge branch 'federicariva:main' into main",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/federicariva/MidbootcampProject/commits/c7acb872835aea6b7c67322c72dfcbdeafe61a5d'},
#     {'sha': '2d03291c42ac8eabdb479ba9277f2cc41335dfb3',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'Update README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/federicariva/MidbootcampProject/commits/2d03291c42ac8eabdb479ba9277f2cc41335dfb3'},
#     {'sha': '547cace593e828f4ffb2496094003b0234770e68',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'Images',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/federicariva/MidbootcampProject/commits/547cace593e828f4ffb2496094003b0234770e68'},
#     {'sha': 'b8fe06062b28a2b9281283259ee4c52fe533dcce',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': "Merge branch 'main' of https://github.com/cathvos/MidbootcampProject",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/federicariva/MidbootcampProject/commits/b8fe06062b28a2b9281283259ee4c52fe533dcce'},
#     {'sha': '15e639672201bb3401cacd681d7325f0cee81171',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': "Merge branch 'federicariva:main' into main",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/federicariva/MidbootcampProject/commits/15e639672201bb3401cacd681d7325f0cee81171'},
#     {'sha': '2d4d06d7ee69587ed5428892b038a0a00eb562ea',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'project',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/federicariva/MidbootcampProject/commits/2d4d06d7ee69587ed5428892b038a0a00eb562ea'},
#     {'sha': '95ae7a92c52bb2f33ae0944b4a7b323458dbf307',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'Update README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/federicariva/MidbootcampProject/commits/95ae7a92c52bb2f33ae0944b4a7b323458dbf307'},
#     {'sha': 'fd06d4d588f1e3203a209f0700a7e1c91f1b79a7',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': "Merge branch 'federicariva:main' into main",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/federicariva/MidbootcampProject/commits/fd06d4d588f1e3203a209f0700a7e1c91f1b79a7'},
#     {'sha': 'f8623ec490eca5ba683f16433f7eebba827c34c7',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'Update README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/federicariva/MidbootcampProject/commits/f8623ec490eca5ba683f16433f7eebba827c34c7'},
#     {'sha': 'd8bd84df3c7dbd4434c74e65c85bb8312cc75e43',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'Update README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/federicariva/MidbootcampProject/commits/d8bd84df3c7dbd4434c74e65c85bb8312cc75e43'},
#     {'sha': '8dd721ffab7e7ebbf8233150e9c53c81e32d3b41',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': "Merge branch 'main' of https://github.com/cathvos/MidbootcampProject",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/federicariva/MidbootcampProject/commits/8dd721ffab7e7ebbf8233150e9c53c81e32d3b41'},
#     {'sha': '7656ac05c765f31e2d5ff670108afa308e9e6fcf',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'Update README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/federicariva/MidbootcampProject/commits/7656ac05c765f31e2d5ff670108afa308e9e6fcf'},
#     {'sha': '9acbac7618a9b62ef26352b0404f86dd6cfc018c',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'image',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/federicariva/MidbootcampProject/commits/9acbac7618a9b62ef26352b0404f86dd6cfc018c'},
#     {'sha': 'd6e808384c9e4c5ddae5b78c43cf087feab18947',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'Update README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/federicariva/MidbootcampProject/commits/d6e808384c9e4c5ddae5b78c43cf087feab18947'},
#     {'sha': '1694031b81cf16017646a551df72b72f1e03fab7',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'Update README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/federicariva/MidbootcampProject/commits/1694031b81cf16017646a551df72b72f1e03fab7'},
#     {'sha': '463b34b8432602ff105464fe013b4752bbb76001',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'Update README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/federicariva/MidbootcampProject/commits/463b34b8432602ff105464fe013b4752bbb76001'},
#     {'sha': '9fc8541b6ced3154c100fbe525cc1dbea01da0e4',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'Update README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/federicariva/MidbootcampProject/commits/9fc8541b6ced3154c100fbe525cc1dbea01da0e4'},
#     {'sha': '8917899ac9e7b86583c07ec6e63cef6869c56736',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'image',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/federicariva/MidbootcampProject/commits/8917899ac9e7b86583c07ec6e63cef6869c56736'},
#     {'sha': '53ddaf4ed75f1529cdb3d306c1fdd360bc61dabc',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': "Merge branch 'main' of https://github.com/cathvos/MidbootcampProject",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/federicariva/MidbootcampProject/commits/53ddaf4ed75f1529cdb3d306c1fdd360bc61dabc'}]},
#   'public': True,
#   'created_at': '2022-05-12T18:34:58Z'},
#  {'id': '21760866703',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 101712996,
#    'login': 'cathvos',
#    'display_login': 'cathvos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cathvos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?'},
#   'repo': {'id': 490211118,
#    'name': 'federicariva/MidbootcampProject',
#    'url': 'https://api.github.com/repos/federicariva/MidbootcampProject'},
#   'payload': {'action': 'closed',
#    'number': 2,
#    'pull_request': {'url': 'https://api.github.com/repos/federicariva/MidbootcampProject/pulls/2',
#     'id': 935149830,
#     'node_id': 'PR_kwDOHTgHLs43vUEG',
#     'html_url': 'https://github.com/federicariva/MidbootcampProject/pull/2',
#     'diff_url': 'https://github.com/federicariva/MidbootcampProject/pull/2.diff',
#     'patch_url': 'https://github.com/federicariva/MidbootcampProject/pull/2.patch',
#     'issue_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/issues/2',
#     'number': 2,
#     'state': 'closed',
#     'locked': False,
#     'title': 'please pull',
#     'user': {'login': 'cathvos',
#      'id': 101712996,
#      'node_id': 'U_kgDOBhAEZA',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/cathvos',
#      'html_url': 'https://github.com/cathvos',
#      'followers_url': 'https://api.github.com/users/cathvos/followers',
#      'following_url': 'https://api.github.com/users/cathvos/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/cathvos/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/cathvos/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/cathvos/subscriptions',
#      'organizations_url': 'https://api.github.com/users/cathvos/orgs',
#      'repos_url': 'https://api.github.com/users/cathvos/repos',
#      'events_url': 'https://api.github.com/users/cathvos/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/cathvos/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2022-05-12T18:34:47Z',
#     'updated_at': '2022-05-12T18:34:56Z',
#     'closed_at': '2022-05-12T18:34:55Z',
#     'merged_at': '2022-05-12T18:34:55Z',
#     'merge_commit_sha': '2f76f83df73eee6be05baaabb84c081ca730e035',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/pulls/2/commits',
#     'review_comments_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/pulls/2/comments',
#     'review_comment_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/issues/2/comments',
#     'statuses_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/statuses/e619ee64f1e856fde49a9a08fdd42bbb5fa29ba2',
#     'head': {'label': 'cathvos:main',
#      'ref': 'main',
#      'sha': 'e619ee64f1e856fde49a9a08fdd42bbb5fa29ba2',
#      'user': {'login': 'cathvos',
#       'id': 101712996,
#       'node_id': 'U_kgDOBhAEZA',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/cathvos',
#       'html_url': 'https://github.com/cathvos',
#       'followers_url': 'https://api.github.com/users/cathvos/followers',
#       'following_url': 'https://api.github.com/users/cathvos/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/cathvos/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/cathvos/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/cathvos/subscriptions',
#       'organizations_url': 'https://api.github.com/users/cathvos/orgs',
#       'repos_url': 'https://api.github.com/users/cathvos/repos',
#       'events_url': 'https://api.github.com/users/cathvos/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/cathvos/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 490216306,
#       'node_id': 'R_kgDOHTgbcg',
#       'name': 'MidbootcampProject',
#       'full_name': 'cathvos/MidbootcampProject',
#       'private': False,
#       'owner': {'login': 'cathvos',
#        'id': 101712996,
#        'node_id': 'U_kgDOBhAEZA',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/cathvos',
#        'html_url': 'https://github.com/cathvos',
#        'followers_url': 'https://api.github.com/users/cathvos/followers',
#        'following_url': 'https://api.github.com/users/cathvos/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/cathvos/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/cathvos/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/cathvos/subscriptions',
#        'organizations_url': 'https://api.github.com/users/cathvos/orgs',
#        'repos_url': 'https://api.github.com/users/cathvos/repos',
#        'events_url': 'https://api.github.com/users/cathvos/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/cathvos/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/cathvos/MidbootcampProject',
#       'description': 'project week 5',
#       'fork': True,
#       'url': 'https://api.github.com/repos/cathvos/MidbootcampProject',
#       'forks_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/forks',
#       'keys_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/teams',
#       'hooks_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/hooks',
#       'issue_events_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/events',
#       'assignees_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/tags',
#       'blobs_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/languages',
#       'stargazers_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/stargazers',
#       'contributors_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/contributors',
#       'subscribers_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/subscribers',
#       'subscription_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/subscription',
#       'commits_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/merges',
#       'archive_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/downloads',
#       'issues_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/deployments',
#       'created_at': '2022-05-09T09:26:51Z',
#       'updated_at': '2022-05-10T10:39:46Z',
#       'pushed_at': '2022-05-12T18:32:28Z',
#       'git_url': 'git://github.com/cathvos/MidbootcampProject.git',
#       'ssh_url': 'git@github.com:cathvos/MidbootcampProject.git',
#       'clone_url': 'https://github.com/cathvos/MidbootcampProject.git',
#       'svn_url': 'https://github.com/cathvos/MidbootcampProject',
#       'homepage': None,
#       'size': 11131,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Jupyter Notebook',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'federicariva:main',
#      'ref': 'main',
#      'sha': 'f218bffa51c9321d66403a4a4d33f76ae2fcd98d',
#      'user': {'login': 'federicariva',
#       'id': 65666003,
#       'node_id': 'MDQ6VXNlcjY1NjY2MDAz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/65666003?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/federicariva',
#       'html_url': 'https://github.com/federicariva',
#       'followers_url': 'https://api.github.com/users/federicariva/followers',
#       'following_url': 'https://api.github.com/users/federicariva/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/federicariva/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/federicariva/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/federicariva/subscriptions',
#       'organizations_url': 'https://api.github.com/users/federicariva/orgs',
#       'repos_url': 'https://api.github.com/users/federicariva/repos',
#       'events_url': 'https://api.github.com/users/federicariva/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/federicariva/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 490211118,
#       'node_id': 'R_kgDOHTgHLg',
#       'name': 'MidbootcampProject',
#       'full_name': 'federicariva/MidbootcampProject',
#       'private': False,
#       'owner': {'login': 'federicariva',
#        'id': 65666003,
#        'node_id': 'MDQ6VXNlcjY1NjY2MDAz',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/65666003?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/federicariva',
#        'html_url': 'https://github.com/federicariva',
#        'followers_url': 'https://api.github.com/users/federicariva/followers',
#        'following_url': 'https://api.github.com/users/federicariva/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/federicariva/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/federicariva/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/federicariva/subscriptions',
#        'organizations_url': 'https://api.github.com/users/federicariva/orgs',
#        'repos_url': 'https://api.github.com/users/federicariva/repos',
#        'events_url': 'https://api.github.com/users/federicariva/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/federicariva/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/federicariva/MidbootcampProject',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/federicariva/MidbootcampProject',
#       'forks_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/forks',
#       'keys_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/teams',
#       'hooks_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/hooks',
#       'issue_events_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/events',
#       'assignees_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/tags',
#       'blobs_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/languages',
#       'stargazers_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/stargazers',
#       'contributors_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/contributors',
#       'subscribers_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/subscribers',
#       'subscription_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/subscription',
#       'commits_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/merges',
#       'archive_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/downloads',
#       'issues_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/deployments',
#       'created_at': '2022-05-09T09:11:28Z',
#       'updated_at': '2022-05-10T10:39:32Z',
#       'pushed_at': '2022-05-12T18:34:55Z',
#       'git_url': 'git://github.com/federicariva/MidbootcampProject.git',
#       'ssh_url': 'git@github.com:federicariva/MidbootcampProject.git',
#       'clone_url': 'https://github.com/federicariva/MidbootcampProject.git',
#       'svn_url': 'https://github.com/federicariva/MidbootcampProject',
#       'homepage': None,
#       'size': 8114,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Jupyter Notebook',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 1,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/federicariva/MidbootcampProject/pulls/2'},
#      'html': {'href': 'https://github.com/federicariva/MidbootcampProject/pull/2'},
#      'issue': {'href': 'https://api.github.com/repos/federicariva/MidbootcampProject/issues/2'},
#      'comments': {'href': 'https://api.github.com/repos/federicariva/MidbootcampProject/issues/2/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/federicariva/MidbootcampProject/pulls/2/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/federicariva/MidbootcampProject/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/federicariva/MidbootcampProject/pulls/2/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/federicariva/MidbootcampProject/statuses/e619ee64f1e856fde49a9a08fdd42bbb5fa29ba2'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'cathvos',
#      'id': 101712996,
#      'node_id': 'U_kgDOBhAEZA',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/cathvos',
#      'html_url': 'https://github.com/cathvos',
#      'followers_url': 'https://api.github.com/users/cathvos/followers',
#      'following_url': 'https://api.github.com/users/cathvos/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/cathvos/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/cathvos/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/cathvos/subscriptions',
#      'organizations_url': 'https://api.github.com/users/cathvos/orgs',
#      'repos_url': 'https://api.github.com/users/cathvos/repos',
#      'events_url': 'https://api.github.com/users/cathvos/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/cathvos/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 25,
#     'additions': 1811,
#     'deletions': 40,
#     'changed_files': 10}},
#   'public': True,
#   'created_at': '2022-05-12T18:34:56Z'},
#  {'id': '21760864431',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 101712996,
#    'login': 'cathvos',
#    'display_login': 'cathvos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cathvos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?'},
#   'repo': {'id': 490211118,
#    'name': 'federicariva/MidbootcampProject',
#    'url': 'https://api.github.com/repos/federicariva/MidbootcampProject'},
#   'payload': {'action': 'opened',
#    'number': 2,
#    'pull_request': {'url': 'https://api.github.com/repos/federicariva/MidbootcampProject/pulls/2',
#     'id': 935149830,
#     'node_id': 'PR_kwDOHTgHLs43vUEG',
#     'html_url': 'https://github.com/federicariva/MidbootcampProject/pull/2',
#     'diff_url': 'https://github.com/federicariva/MidbootcampProject/pull/2.diff',
#     'patch_url': 'https://github.com/federicariva/MidbootcampProject/pull/2.patch',
#     'issue_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/issues/2',
#     'number': 2,
#     'state': 'open',
#     'locked': False,
#     'title': 'please pull',
#     'user': {'login': 'cathvos',
#      'id': 101712996,
#      'node_id': 'U_kgDOBhAEZA',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/cathvos',
#      'html_url': 'https://github.com/cathvos',
#      'followers_url': 'https://api.github.com/users/cathvos/followers',
#      'following_url': 'https://api.github.com/users/cathvos/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/cathvos/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/cathvos/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/cathvos/subscriptions',
#      'organizations_url': 'https://api.github.com/users/cathvos/orgs',
#      'repos_url': 'https://api.github.com/users/cathvos/repos',
#      'events_url': 'https://api.github.com/users/cathvos/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/cathvos/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2022-05-12T18:34:47Z',
#     'updated_at': '2022-05-12T18:34:47Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/pulls/2/commits',
#     'review_comments_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/pulls/2/comments',
#     'review_comment_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/issues/2/comments',
#     'statuses_url': 'https://api.github.com/repos/federicariva/MidbootcampProject/statuses/e619ee64f1e856fde49a9a08fdd42bbb5fa29ba2',
#     'head': {'label': 'cathvos:main',
#      'ref': 'main',
#      'sha': 'e619ee64f1e856fde49a9a08fdd42bbb5fa29ba2',
#      'user': {'login': 'cathvos',
#       'id': 101712996,
#       'node_id': 'U_kgDOBhAEZA',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/cathvos',
#       'html_url': 'https://github.com/cathvos',
#       'followers_url': 'https://api.github.com/users/cathvos/followers',
#       'following_url': 'https://api.github.com/users/cathvos/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/cathvos/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/cathvos/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/cathvos/subscriptions',
#       'organizations_url': 'https://api.github.com/users/cathvos/orgs',
#       'repos_url': 'https://api.github.com/users/cathvos/repos',
#       'events_url': 'https://api.github.com/users/cathvos/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/cathvos/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 490216306,
#       'node_id': 'R_kgDOHTgbcg',
#       'name': 'MidbootcampProject',
#       'full_name': 'cathvos/MidbootcampProject',
#       'private': False,
#       'owner': {'login': 'cathvos',
#        'id': 101712996,
#        'node_id': 'U_kgDOBhAEZA',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/cathvos',
#        'html_url': 'https://github.com/cathvos',
#        'followers_url': 'https://api.github.com/users/cathvos/followers',
#        'following_url': 'https://api.github.com/users/cathvos/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/cathvos/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/cathvos/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/cathvos/subscriptions',
#        'organizations_url': 'https://api.github.com/users/cathvos/orgs',
#        'repos_url': 'https://api.github.com/users/cathvos/repos',
#        'events_url': 'https://api.github.com/users/cathvos/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/cathvos/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/cathvos/MidbootcampProject',
#       'description': 'project week 5',
#       'fork': True,
#       'url': 'https://api.github.com/repos/cathvos/MidbootcampProject',
#       'forks_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/forks',
#       'keys_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/teams',
#       'hooks_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/hooks',
#       'issue_events_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/events',
#       'assignees_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/tags',
#       'blobs_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/languages',
#       'stargazers_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/stargazers',
#       'contributors_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/contributors',
#       'subscribers_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/subscribers',
#       'subscription_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/subscription',
#       'commits_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/merges',
#       'archive_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/downloads',
#       'issues_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/cathvos/MidbootcampProject/deployments',
#       'created_at': '2022-05-09T09:26:51Z',
#       'updated_at': '2022-05-10T10:39:46Z',
#       'pushed_at': '2022-05-12T18:32:28Z',
#       'git_url': 'git://github.com/cathvos/MidbootcampProject.git',
#       'ssh_url': 'git@github.com:cathvos/MidbootcampProject.git',
#       'clone_url': 'https://github.com/cathvos/MidbootcampProject.git',
#       'svn_url': 'https://github.com/cathvos/MidbootcampProject',
#       'homepage': None,
#       'size': 11131,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Jupyter Notebook',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'federicariva:main',
#      'ref': 'main',
#      'sha': 'f218bffa51c9321d66403a4a4d33f76ae2fcd98d',
#      'user': {'login': 'federicariva',
#       'id': 65666003,
#       'node_id': 'MDQ6VXNlcjY1NjY2MDAz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/65666003?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/federicariva',
#       'html_url': 'https://github.com/federicariva',
#       'followers_url': 'https://api.github.com/users/federicariva/followers',
#       'following_url': 'https://api.github.com/users/federicariva/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/federicariva/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/federicariva/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/federicariva/subscriptions',
#       'organizations_url': 'https://api.github.com/users/federicariva/orgs',
#       'repos_url': 'https://api.github.com/users/federicariva/repos',
#       'events_url': 'https://api.github.com/users/federicariva/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/federicariva/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 490211118,
#       'node_id': 'R_kgDOHTgHLg',
#       'name': 'MidbootcampProject',
#       'full_name': 'federicariva/MidbootcampProject',
#       'private': False,
#       'owner': {'login': 'federicariva',
#        'id': 65666003,
#        'node_id': 'MDQ6VXNlcjY1NjY2MDAz',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/65666003?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/federicariva',
#        'html_url': 'https://github.com/federicariva',
#        'followers_url': 'https://api.github.com/users/federicariva/followers',
#        'following_url': 'https://api.github.com/users/federicariva/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/federicariva/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/federicariva/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/federicariva/subscriptions',
#        'organizations_url': 'https://api.github.com/users/federicariva/orgs',
#        'repos_url': 'https://api.github.com/users/federicariva/repos',
#        'events_url': 'https://api.github.com/users/federicariva/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/federicariva/received_events',
#        'type': 'User',
# ...
#    'commits': [{'sha': '9acbac7618a9b62ef26352b0404f86dd6cfc018c',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'image',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/9acbac7618a9b62ef26352b0404f86dd6cfc018c'}]},
#   'public': True,
#   'created_at': '2022-05-12T17:40:48Z'},
#  {'id': '21759946973',
#   'type': 'PushEvent',
#   'actor': {'id': 101712996,
#    'login': 'cathvos',
#    'display_login': 'cathvos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cathvos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?'},
#   'repo': {'id': 490216306,
#    'name': 'cathvos/MidbootcampProject',
#    'url': 'https://api.github.com/repos/cathvos/MidbootcampProject'},
#   'payload': {'push_id': 9867345585,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '7656ac05c765f31e2d5ff670108afa308e9e6fcf',
#    'before': '8dd721ffab7e7ebbf8233150e9c53c81e32d3b41',
#    'commits': [{'sha': '7656ac05c765f31e2d5ff670108afa308e9e6fcf',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'Update README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/7656ac05c765f31e2d5ff670108afa308e9e6fcf'}]},
#   'public': True,
#   'created_at': '2022-05-12T17:37:32Z'},
#  {'id': '21759831930',
#   'type': 'PushEvent',
#   'actor': {'id': 101712996,
#    'login': 'cathvos',
#    'display_login': 'cathvos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cathvos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?'},
#   'repo': {'id': 490216306,
#    'name': 'cathvos/MidbootcampProject',
#    'url': 'https://api.github.com/repos/cathvos/MidbootcampProject'},
#   'payload': {'push_id': 9867289263,
#    'size': 4,
#    'distinct_size': 4,
#    'ref': 'refs/heads/main',
#    'head': '8dd721ffab7e7ebbf8233150e9c53c81e32d3b41',
#    'before': 'd8bd84df3c7dbd4434c74e65c85bb8312cc75e43',
#    'commits': [{'sha': '547cace593e828f4ffb2496094003b0234770e68',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'Images',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/547cace593e828f4ffb2496094003b0234770e68'},
#     {'sha': 'b8fe06062b28a2b9281283259ee4c52fe533dcce',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': "Merge branch 'main' of https://github.com/cathvos/MidbootcampProject",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/b8fe06062b28a2b9281283259ee4c52fe533dcce'},
#     {'sha': '2d4d06d7ee69587ed5428892b038a0a00eb562ea',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'project',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/2d4d06d7ee69587ed5428892b038a0a00eb562ea'},
#     {'sha': '8dd721ffab7e7ebbf8233150e9c53c81e32d3b41',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': "Merge branch 'main' of https://github.com/cathvos/MidbootcampProject",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/8dd721ffab7e7ebbf8233150e9c53c81e32d3b41'}]},
#   'public': True,
#   'created_at': '2022-05-12T17:30:29Z'},
#  {'id': '21759797934',
#   'type': 'PushEvent',
#   'actor': {'id': 101712996,
#    'login': 'cathvos',
#    'display_login': 'cathvos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cathvos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?'},
#   'repo': {'id': 490216306,
#    'name': 'cathvos/MidbootcampProject',
#    'url': 'https://api.github.com/repos/cathvos/MidbootcampProject'},
#   'payload': {'push_id': 9867272756,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd8bd84df3c7dbd4434c74e65c85bb8312cc75e43',
#    'before': 'f8623ec490eca5ba683f16433f7eebba827c34c7',
#    'commits': [{'sha': 'd8bd84df3c7dbd4434c74e65c85bb8312cc75e43',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'Update README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/d8bd84df3c7dbd4434c74e65c85bb8312cc75e43'}]},
#   'public': True,
#   'created_at': '2022-05-12T17:28:28Z'},
#  {'id': '21759604004',
#   'type': 'PushEvent',
#   'actor': {'id': 101712996,
#    'login': 'cathvos',
#    'display_login': 'cathvos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cathvos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?'},
#   'repo': {'id': 490216306,
#    'name': 'cathvos/MidbootcampProject',
#    'url': 'https://api.github.com/repos/cathvos/MidbootcampProject'},
#   'payload': {'push_id': 9867176711,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f8623ec490eca5ba683f16433f7eebba827c34c7',
#    'before': 'fd06d4d588f1e3203a209f0700a7e1c91f1b79a7',
#    'commits': [{'sha': 'f8623ec490eca5ba683f16433f7eebba827c34c7',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'Update README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/f8623ec490eca5ba683f16433f7eebba827c34c7'}]},
#   'public': True,
#   'created_at': '2022-05-12T17:16:41Z'},
#  {'id': '21759521595',
#   'type': 'PushEvent',
#   'actor': {'id': 101712996,
#    'login': 'cathvos',
#    'display_login': 'cathvos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cathvos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?'},
#   'repo': {'id': 490216306,
#    'name': 'cathvos/MidbootcampProject',
#    'url': 'https://api.github.com/repos/cathvos/MidbootcampProject'},
#   'payload': {'push_id': 9867136578,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': 'fd06d4d588f1e3203a209f0700a7e1c91f1b79a7',
#    'before': '95ae7a92c52bb2f33ae0944b4a7b323458dbf307',
#    'commits': [{'sha': 'f992ee6355bb940b46427cb8d3175e4e9eb99bc4',
#      'author': {'email': 'federicayriva@gmail.com', 'name': 'federicariva'},
#      'message': 'midbootcamp_project',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/f992ee6355bb940b46427cb8d3175e4e9eb99bc4'},
#     {'sha': 'fd06d4d588f1e3203a209f0700a7e1c91f1b79a7',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': "Merge branch 'federicariva:main' into main",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/fd06d4d588f1e3203a209f0700a7e1c91f1b79a7'}]},
#   'public': True,
#   'created_at': '2022-05-12T17:11:46Z'},
#  {'id': '21759487627',
#   'type': 'PushEvent',
#   'actor': {'id': 101712996,
#    'login': 'cathvos',
#    'display_login': 'cathvos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cathvos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?'},
#   'repo': {'id': 490216306,
#    'name': 'cathvos/MidbootcampProject',
#    'url': 'https://api.github.com/repos/cathvos/MidbootcampProject'},
#   'payload': {'push_id': 9867120251,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '95ae7a92c52bb2f33ae0944b4a7b323458dbf307',
#    'before': '15e639672201bb3401cacd681d7325f0cee81171',
#    'commits': [{'sha': '95ae7a92c52bb2f33ae0944b4a7b323458dbf307',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'Update README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/95ae7a92c52bb2f33ae0944b4a7b323458dbf307'}]},
#   'public': True,
#   'created_at': '2022-05-12T17:09:47Z'},
#  {'id': '21759307769',
#   'type': 'PushEvent',
#   'actor': {'id': 101712996,
#    'login': 'cathvos',
#    'display_login': 'cathvos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cathvos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?'},
#   'repo': {'id': 490216306,
#    'name': 'cathvos/MidbootcampProject',
#    'url': 'https://api.github.com/repos/cathvos/MidbootcampProject'},
#   'payload': {'push_id': 9867031192,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': '15e639672201bb3401cacd681d7325f0cee81171',
#    'before': '2d03291c42ac8eabdb479ba9277f2cc41335dfb3',
#    'commits': [{'sha': 'da084ce5e39b86929bedf7b4c0607cc62b56afaa',
#      'author': {'email': 'federicayriva@gmail.com', 'name': 'federicariva'},
#      'message': 'code',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/da084ce5e39b86929bedf7b4c0607cc62b56afaa'},
#     {'sha': '15e639672201bb3401cacd681d7325f0cee81171',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': "Merge branch 'federicariva:main' into main",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/15e639672201bb3401cacd681d7325f0cee81171'}]},
#   'public': True,
#   'created_at': '2022-05-12T16:59:06Z'},
#  {'id': '21757107215',
#   'type': 'PushEvent',
#   'actor': {'id': 101712996,
#    'login': 'cathvos',
#    'display_login': 'cathvos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cathvos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?'},
#   'repo': {'id': 490216306,
#    'name': 'cathvos/MidbootcampProject',
#    'url': 'https://api.github.com/repos/cathvos/MidbootcampProject'},
#   'payload': {'push_id': 9865970126,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2d03291c42ac8eabdb479ba9277f2cc41335dfb3',
#    'before': 'c7acb872835aea6b7c67322c72dfcbdeafe61a5d',
#    'commits': [{'sha': '2d03291c42ac8eabdb479ba9277f2cc41335dfb3',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'Update README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/2d03291c42ac8eabdb479ba9277f2cc41335dfb3'}]},
#   'public': True,
#   'created_at': '2022-05-12T15:05:29Z'},
#  {'id': '21756535291',
#   'type': 'PushEvent',
#   'actor': {'id': 101712996,
#    'login': 'cathvos',
#    'display_login': 'cathvos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cathvos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?'},
#   'repo': {'id': 490216306,
#    'name': 'cathvos/MidbootcampProject',
#    'url': 'https://api.github.com/repos/cathvos/MidbootcampProject'},
#   'payload': {'push_id': 9865695029,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/main',
#    'head': 'c7acb872835aea6b7c67322c72dfcbdeafe61a5d',
#    'before': 'd153029ca1a5aa63b0dc53850e9096bd1d0afe67',
#    'commits': [{'sha': '69f85dd36a9bd3a53548d87abfd64492d4d5b7af',
#      'author': {'email': 'federicayriva@gmail.com', 'name': 'federicariva'},
#      'message': 'code',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/69f85dd36a9bd3a53548d87abfd64492d4d5b7af'},
#     {'sha': '509275cd307e4ac38eaf6feeb19df6f7927e036f',
#      'author': {'email': 'federicayriva@gmail.com', 'name': 'federicariva'},
#      'message': 'code',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/509275cd307e4ac38eaf6feeb19df6f7927e036f'},
#     {'sha': 'c7acb872835aea6b7c67322c72dfcbdeafe61a5d',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': "Merge branch 'federicariva:main' into main",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/c7acb872835aea6b7c67322c72dfcbdeafe61a5d'}]},
#   'public': True,
#   'created_at': '2022-05-12T14:40:37Z'},
#  {'id': '21748459035',
#   'type': 'PushEvent',
#   'actor': {'id': 101712996,
#    'login': 'cathvos',
#    'display_login': 'cathvos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cathvos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?'},
#   'repo': {'id': 490216306,
#    'name': 'cathvos/MidbootcampProject',
#    'url': 'https://api.github.com/repos/cathvos/MidbootcampProject'},
#   'payload': {'push_id': 9861746222,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd153029ca1a5aa63b0dc53850e9096bd1d0afe67',
#    'before': 'b9dc9c85f669ab3d97a3afe95dec3904a2a17376',
#    'commits': [{'sha': 'd153029ca1a5aa63b0dc53850e9096bd1d0afe67',
#      'author': {'email': '101712996+cathvos@users.noreply.github.com',
#       'name': 'cathvos'},
#      'message': 'project',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/d153029ca1a5aa63b0dc53850e9096bd1d0afe67'}]},
#   'public': True,
#   'created_at': '2022-05-12T07:57:25Z'},
#  {'id': '21737049581',
#   'type': 'PushEvent',
#   'actor': {'id': 101712996,
#    'login': 'cathvos',
#    'display_login': 'cathvos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cathvos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?'},
#   'repo': {'id': 490216306,
#    'name': 'cathvos/MidbootcampProject',
#    'url': 'https://api.github.com/repos/cathvos/MidbootcampProject'},
#   'payload': {'push_id': 9855986658,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/main',
#    'head': 'b9dc9c85f669ab3d97a3afe95dec3904a2a17376',
#    'before': 'cca213e2f4027b221d4ea8caf7d0385624222d28',
#    'commits': [{'sha': '87f2ab96bb2f752e81a5451ed9634596bceed3ff',
#      'author': {'email': 'federicayriva@gmail.com', 'name': 'federicariva'},
#      'message': 'code',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/87f2ab96bb2f752e81a5451ed9634596bceed3ff'},
#     {'sha': 'e7cdf8fe2bd247719709d6dc5e886bf2bcde2f91',
#      'author': {'email': 'federicayriva@gmail.com', 'name': 'federicariva'},
#      'message': 'dataset',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/e7cdf8fe2bd247719709d6dc5e886bf2bcde2f91'},
#     {'sha': 'b9dc9c85f669ab3d97a3afe95dec3904a2a17376',
#      'author': {'email': 'federicayriva@gmail.com', 'name': 'federicariva'},
#      'message': 'code',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/b9dc9c85f669ab3d97a3afe95dec3904a2a17376'}]},
#   'public': True,
#   'created_at': '2022-05-11T16:35:01Z'},
#  {'id': '21707151310',
#   'type': 'PushEvent',
#   'actor': {'id': 101712996,
#    'login': 'cathvos',
#    'display_login': 'cathvos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cathvos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101712996?'},
#   'repo': {'id': 490216306,
#    'name': 'cathvos/MidbootcampProject',
#    'url': 'https://api.github.com/repos/cathvos/MidbootcampProject'},
#   'payload': {'push_id': 9841436048,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': 'cca213e2f4027b221d4ea8caf7d0385624222d28',
#    'before': 'b57002379d6ef15738ac14271c39b9432e502f0f',
#    'commits': [{'sha': '7903926b6149ffe76c62df5dce27818b649a9651',
#      'author': {'email': 'federicayriva@gmail.com', 'name': 'federicariva'},
#      'message': 'code',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/7903926b6149ffe76c62df5dce27818b649a9651'},
#     {'sha': 'cca213e2f4027b221d4ea8caf7d0385624222d28',
#      'author': {'email': 'federicayriva@gmail.com', 'name': 'federicariva'},
#      'message': 'data',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cathvos/MidbootcampProject/commits/cca213e2f4027b221d4ea8caf7d0385624222d28'}]},
#   'public': True,
#   'created_at': '2022-05-10T10:39:43Z'}]

# %%
import pandas as pd

# %%
pd.DataFrame(github_response.json())
# Out:
#              id              type  \
# 0   21957645509         PushEvent
# 1   21850820150         PushEvent
# 2   21831572049         PushEvent
# 3   21831141340         PushEvent
# 4   21807952642         PushEvent
# 5   21760867394         PushEvent
# 6   21760866703  PullRequestEvent
# 7   21760864431  PullRequestEvent
# 8   21760827447         PushEvent
# 9   21760369330         PushEvent
# 10  21760337772         PushEvent
# 11  21760259179         PushEvent
# 12  21760231854         PushEvent
# 13  21760131128         PushEvent
# 14  21760117568         PushEvent
# 15  21760047725         PushEvent
# 16  21760021458         PushEvent
# 17  21760000238         PushEvent
# 18  21759946973         PushEvent
# 19  21759831930         PushEvent
# 20  21759797934         PushEvent
# 21  21759604004         PushEvent
# 22  21759521595         PushEvent
# 23  21759487627         PushEvent
# 24  21759307769         PushEvent
# 25  21757107215         PushEvent
# 26  21756535291         PushEvent
# 27  21748459035         PushEvent
# 28  21737049581         PushEvent
# 29  21707151310         PushEvent
#
#                                                 actor  \
# 0   {'id': 101712996, 'login': 'cathvos', 'display...
# 1   {'id': 101712996, 'login': 'cathvos', 'display...
# 2   {'id': 101712996, 'login': 'cathvos', 'display...
# 3   {'id': 101712996, 'login': 'cathvos', 'display...
# 4   {'id': 101712996, 'login': 'cathvos', 'display...
# 5   {'id': 101712996, 'login': 'cathvos', 'display...
# 6   {'id': 101712996, 'login': 'cathvos', 'display...
# 7   {'id': 101712996, 'login': 'cathvos', 'display...
# 8   {'id': 101712996, 'login': 'cathvos', 'display...
# 9   {'id': 101712996, 'login': 'cathvos', 'display...
# 10  {'id': 101712996, 'login': 'cathvos', 'display...
# 11  {'id': 101712996, 'login': 'cathvos', 'display...
# 12  {'id': 101712996, 'login': 'cathvos', 'display...
# 13  {'id': 101712996, 'login': 'cathvos', 'display...
# 14  {'id': 101712996, 'login': 'cathvos', 'display...
# 15  {'id': 101712996, 'login': 'cathvos', 'display...
# 16  {'id': 101712996, 'login': 'cathvos', 'display...
# 17  {'id': 101712996, 'login': 'cathvos', 'display...
# 18  {'id': 101712996, 'login': 'cathvos', 'display...
# 19  {'id': 101712996, 'login': 'cathvos', 'display...
# 20  {'id': 101712996, 'login': 'cathvos', 'display...
# 21  {'id': 101712996, 'login': 'cathvos', 'display...
# 22  {'id': 101712996, 'login': 'cathvos', 'display...
# 23  {'id': 101712996, 'login': 'cathvos', 'display...
# 24  {'id': 101712996, 'login': 'cathvos', 'display...
# 25  {'id': 101712996, 'login': 'cathvos', 'display...
# 26  {'id': 101712996, 'login': 'cathvos', 'display...
# 27  {'id': 101712996, 'login': 'cathvos', 'display...
# 28  {'id': 101712996, 'login': 'cathvos', 'display...
# 29  {'id': 101712996, 'login': 'cathvos', 'display...
#
#                                                  repo  \
# 0   {'id': 480380113, 'name': 'cathvos/IronCath', ...
# 1   {'id': 480380113, 'name': 'cathvos/IronCath', ...
# 2   {'id': 480380113, 'name': 'cathvos/IronCath', ...
# 3   {'id': 480380113, 'name': 'cathvos/IronCath', ...
# 4   {'id': 481923883, 'name': 'cathvos/BCNDATA2022...
# 5   {'id': 490211118, 'name': 'federicariva/Midboo...
# 6   {'id': 490211118, 'name': 'federicariva/Midboo...
# 7   {'id': 490211118, 'name': 'federicariva/Midboo...
# 8   {'id': 490216306, 'name': 'cathvos/Midbootcamp...
# 9   {'id': 490216306, 'name': 'cathvos/Midbootcamp...
# 10  {'id': 490216306, 'name': 'cathvos/Midbootcamp...
# 11  {'id': 490216306, 'name': 'cathvos/Midbootcamp...
# 12  {'id': 490216306, 'name': 'cathvos/Midbootcamp...
# 13  {'id': 490216306, 'name': 'cathvos/Midbootcamp...
# 14  {'id': 490216306, 'name': 'cathvos/Midbootcamp...
# 15  {'id': 490216306, 'name': 'cathvos/Midbootcamp...
# 16  {'id': 490216306, 'name': 'cathvos/Midbootcamp...
# 17  {'id': 490216306, 'name': 'cathvos/Midbootcamp...
# 18  {'id': 490216306, 'name': 'cathvos/Midbootcamp...
# 19  {'id': 490216306, 'name': 'cathvos/Midbootcamp...
# 20  {'id': 490216306, 'name': 'cathvos/Midbootcamp...
# 21  {'id': 490216306, 'name': 'cathvos/Midbootcamp...
# 22  {'id': 490216306, 'name': 'cathvos/Midbootcamp...
# 23  {'id': 490216306, 'name': 'cathvos/Midbootcamp...
# 24  {'id': 490216306, 'name': 'cathvos/Midbootcamp...
# 25  {'id': 490216306, 'name': 'cathvos/Midbootcamp...
# 26  {'id': 490216306, 'name': 'cathvos/Midbootcamp...
# 27  {'id': 490216306, 'name': 'cathvos/Midbootcamp...
# 28  {'id': 490216306, 'name': 'cathvos/Midbootcamp...
# 29  {'id': 490216306, 'name': 'cathvos/Midbootcamp...
#
#                                               payload  public  \
# 0   {'push_id': 9969208504, 'size': 3, 'distinct_s...    True
# 1   {'push_id': 9914584890, 'size': 1, 'distinct_s...    True
# 2   {'push_id': 9904934180, 'size': 1, 'distinct_s...    True
# 3   {'push_id': 9904722361, 'size': 1, 'distinct_s...    True
# 4   {'push_id': 9893504582, 'size': 8, 'distinct_s...    True
# 5   {'push_id': 9867799745, 'size': 26, 'distinct_...    True
# 6   {'action': 'closed', 'number': 2, 'pull_reques...    True
# 7   {'action': 'opened', 'number': 2, 'pull_reques...    True
# 8   {'push_id': 9867780327, 'size': 2, 'distinct_s...    True
# 9   {'push_id': 9867552481, 'size': 1, 'distinct_s...    True
# 10  {'push_id': 9867537064, 'size': 2, 'distinct_s...    True
# 11  {'push_id': 9867498534, 'size': 1, 'distinct_s...    True
# 12  {'push_id': 9867485263, 'size': 2, 'distinct_s...    True
# 13  {'push_id': 9867435666, 'size': 1, 'distinct_s...    True
# 14  {'push_id': 9867429070, 'size': 1, 'distinct_s...    True
# 15  {'push_id': 9867395049, 'size': 1, 'distinct_s...    True
# 16  {'push_id': 9867382344, 'size': 1, 'distinct_s...    True
# 17  {'push_id': 9867371803, 'size': 1, 'distinct_s...    True
# 18  {'push_id': 9867345585, 'size': 1, 'distinct_s...    True
# 19  {'push_id': 9867289263, 'size': 4, 'distinct_s...    True
# 20  {'push_id': 9867272756, 'size': 1, 'distinct_s...    True
# 21  {'push_id': 9867176711, 'size': 1, 'distinct_s...    True
# 22  {'push_id': 9867136578, 'size': 2, 'distinct_s...    True
# 23  {'push_id': 9867120251, 'size': 1, 'distinct_s...    True
# 24  {'push_id': 9867031192, 'size': 2, 'distinct_s...    True
# 25  {'push_id': 9865970126, 'size': 1, 'distinct_s...    True
# 26  {'push_id': 9865695029, 'size': 3, 'distinct_s...    True
# 27  {'push_id': 9861746222, 'size': 1, 'distinct_s...    True
# 28  {'push_id': 9855986658, 'size': 3, 'distinct_s...    True
# 29  {'push_id': 9841436048, 'size': 2, 'distinct_s...    True
#
#               created_at
# 0   2022-05-24T13:26:14Z
# 1   2022-05-18T09:44:42Z
# 2   2022-05-17T12:44:36Z
# 3   2022-05-17T12:23:42Z
# 4   2022-05-16T12:10:21Z
# 5   2022-05-12T18:34:58Z
# 6   2022-05-12T18:34:56Z
# 7   2022-05-12T18:34:47Z
# 8   2022-05-12T18:32:29Z
# 9   2022-05-12T18:03:53Z
# 10  2022-05-12T18:01:54Z
# 11  2022-05-12T17:57:03Z
# 12  2022-05-12T17:55:21Z
# 13  2022-05-12T17:49:01Z
# 14  2022-05-12T17:48:09Z
# 15  2022-05-12T17:43:49Z
# 16  2022-05-12T17:42:09Z
# 17  2022-05-12T17:40:48Z
# 18  2022-05-12T17:37:32Z
# 19  2022-05-12T17:30:29Z
# 20  2022-05-12T17:28:28Z
# 21  2022-05-12T17:16:41Z
# 22  2022-05-12T17:11:46Z
# 23  2022-05-12T17:09:47Z
# 24  2022-05-12T16:59:06Z
# 25  2022-05-12T15:05:29Z
# 26  2022-05-12T14:40:37Z
# 27  2022-05-12T07:57:25Z
# 28  2022-05-11T16:35:01Z
# 29  2022-05-10T10:39:43Z

# %%
github_df=pd.json_normalize(github_response.json())

# %%
github_df.iloc[:,1:25]
# Out:
#                 type  public            created_at   actor.id actor.login  \
# 0          PushEvent    True  2022-05-24T13:26:14Z  101712996     cathvos
# 1          PushEvent    True  2022-05-18T09:44:42Z  101712996     cathvos
# 2          PushEvent    True  2022-05-17T12:44:36Z  101712996     cathvos
# 3          PushEvent    True  2022-05-17T12:23:42Z  101712996     cathvos
# 4          PushEvent    True  2022-05-16T12:10:21Z  101712996     cathvos
# 5          PushEvent    True  2022-05-12T18:34:58Z  101712996     cathvos
# 6   PullRequestEvent    True  2022-05-12T18:34:56Z  101712996     cathvos
# 7   PullRequestEvent    True  2022-05-12T18:34:47Z  101712996     cathvos
# 8          PushEvent    True  2022-05-12T18:32:29Z  101712996     cathvos
# 9          PushEvent    True  2022-05-12T18:03:53Z  101712996     cathvos
# 10         PushEvent    True  2022-05-12T18:01:54Z  101712996     cathvos
# 11         PushEvent    True  2022-05-12T17:57:03Z  101712996     cathvos
# 12         PushEvent    True  2022-05-12T17:55:21Z  101712996     cathvos
# 13         PushEvent    True  2022-05-12T17:49:01Z  101712996     cathvos
# 14         PushEvent    True  2022-05-12T17:48:09Z  101712996     cathvos
# 15         PushEvent    True  2022-05-12T17:43:49Z  101712996     cathvos
# 16         PushEvent    True  2022-05-12T17:42:09Z  101712996     cathvos
# 17         PushEvent    True  2022-05-12T17:40:48Z  101712996     cathvos
# 18         PushEvent    True  2022-05-12T17:37:32Z  101712996     cathvos
# 19         PushEvent    True  2022-05-12T17:30:29Z  101712996     cathvos
# 20         PushEvent    True  2022-05-12T17:28:28Z  101712996     cathvos
# 21         PushEvent    True  2022-05-12T17:16:41Z  101712996     cathvos
# 22         PushEvent    True  2022-05-12T17:11:46Z  101712996     cathvos
# 23         PushEvent    True  2022-05-12T17:09:47Z  101712996     cathvos
# 24         PushEvent    True  2022-05-12T16:59:06Z  101712996     cathvos
# 25         PushEvent    True  2022-05-12T15:05:29Z  101712996     cathvos
# 26         PushEvent    True  2022-05-12T14:40:37Z  101712996     cathvos
# 27         PushEvent    True  2022-05-12T07:57:25Z  101712996     cathvos
# 28         PushEvent    True  2022-05-11T16:35:01Z  101712996     cathvos
# 29         PushEvent    True  2022-05-10T10:39:43Z  101712996     cathvos
#
#    actor.display_login actor.gravatar_id  \
# 0              cathvos
# 1              cathvos
# 2              cathvos
# 3              cathvos
# 4              cathvos
# 5              cathvos
# 6              cathvos
# 7              cathvos
# 8              cathvos
# 9              cathvos
# 10             cathvos
# 11             cathvos
# 12             cathvos
# 13             cathvos
# 14             cathvos
# 15             cathvos
# 16             cathvos
# 17             cathvos
# 18             cathvos
# 19             cathvos
# 20             cathvos
# 21             cathvos
# 22             cathvos
# 23             cathvos
# 24             cathvos
# 25             cathvos
# 26             cathvos
# 27             cathvos
# 28             cathvos
# 29             cathvos
#
#                                actor.url  \
# 0   https://api.github.com/users/cathvos
# 1   https://api.github.com/users/cathvos
# 2   https://api.github.com/users/cathvos
# 3   https://api.github.com/users/cathvos
# 4   https://api.github.com/users/cathvos
# 5   https://api.github.com/users/cathvos
# 6   https://api.github.com/users/cathvos
# 7   https://api.github.com/users/cathvos
# 8   https://api.github.com/users/cathvos
# 9   https://api.github.com/users/cathvos
# 10  https://api.github.com/users/cathvos
# 11  https://api.github.com/users/cathvos
# 12  https://api.github.com/users/cathvos
# 13  https://api.github.com/users/cathvos
# 14  https://api.github.com/users/cathvos
# 15  https://api.github.com/users/cathvos
# 16  https://api.github.com/users/cathvos
# 17  https://api.github.com/users/cathvos
# 18  https://api.github.com/users/cathvos
# 19  https://api.github.com/users/cathvos
# 20  https://api.github.com/users/cathvos
# 21  https://api.github.com/users/cathvos
# 22  https://api.github.com/users/cathvos
# 23  https://api.github.com/users/cathvos
# 24  https://api.github.com/users/cathvos
# 25  https://api.github.com/users/cathvos
# 26  https://api.github.com/users/cathvos
# 27  https://api.github.com/users/cathvos
# 28  https://api.github.com/users/cathvos
# 29  https://api.github.com/users/cathvos
#
#                                      actor.avatar_url    repo.id  ...  \
# 0   https://avatars.githubusercontent.com/u/101712...  480380113  ...
# 1   https://avatars.githubusercontent.com/u/101712...  480380113  ...
# 2   https://avatars.githubusercontent.com/u/101712...  480380113  ...
# 3   https://avatars.githubusercontent.com/u/101712...  480380113  ...
# 4   https://avatars.githubusercontent.com/u/101712...  481923883  ...
# 5   https://avatars.githubusercontent.com/u/101712...  490211118  ...
# 6   https://avatars.githubusercontent.com/u/101712...  490211118  ...
# 7   https://avatars.githubusercontent.com/u/101712...  490211118  ...
# 8   https://avatars.githubusercontent.com/u/101712...  490216306  ...
# 9   https://avatars.githubusercontent.com/u/101712...  490216306  ...
# 10  https://avatars.githubusercontent.com/u/101712...  490216306  ...
# 11  https://avatars.githubusercontent.com/u/101712...  490216306  ...
# 12  https://avatars.githubusercontent.com/u/101712...  490216306  ...
# 13  https://avatars.githubusercontent.com/u/101712...  490216306  ...
# 14  https://avatars.githubusercontent.com/u/101712...  490216306  ...
# 15  https://avatars.githubusercontent.com/u/101712...  490216306  ...
# 16  https://avatars.githubusercontent.com/u/101712...  490216306  ...
# 17  https://avatars.githubusercontent.com/u/101712...  490216306  ...
# 18  https://avatars.githubusercontent.com/u/101712...  490216306  ...
# 19  https://avatars.githubusercontent.com/u/101712...  490216306  ...
# 20  https://avatars.githubusercontent.com/u/101712...  490216306  ...
# 21  https://avatars.githubusercontent.com/u/101712...  490216306  ...
# 22  https://avatars.githubusercontent.com/u/101712...  490216306  ...
# 23  https://avatars.githubusercontent.com/u/101712...  490216306  ...
# 24  https://avatars.githubusercontent.com/u/101712...  490216306  ...
# 25  https://avatars.githubusercontent.com/u/101712...  490216306  ...
# 26  https://avatars.githubusercontent.com/u/101712...  490216306  ...
# 27  https://avatars.githubusercontent.com/u/101712...  490216306  ...
# 28  https://avatars.githubusercontent.com/u/101712...  490216306  ...
# 29  https://avatars.githubusercontent.com/u/101712...  490216306  ...
#
#    payload.distinct_size      payload.ref  \
# 0                    3.0  refs/heads/main
# 1                    1.0  refs/heads/main
# 2                    1.0  refs/heads/main
# 3                    1.0  refs/heads/main
# 4                    8.0  refs/heads/main
# 5                   26.0  refs/heads/main
# 6                    NaN              NaN
# 7                    NaN              NaN
# 8                    2.0  refs/heads/main
# 9                    1.0  refs/heads/main
# 10                   2.0  refs/heads/main
# 11                   1.0  refs/heads/main
# 12                   2.0  refs/heads/main
# 13                   1.0  refs/heads/main
# 14                   1.0  refs/heads/main
# 15                   1.0  refs/heads/main
# 16                   1.0  refs/heads/main
# 17                   1.0  refs/heads/main
# 18                   1.0  refs/heads/main
# 19                   4.0  refs/heads/main
# 20                   1.0  refs/heads/main
# 21                   1.0  refs/heads/main
# 22                   2.0  refs/heads/main
# 23                   1.0  refs/heads/main
# 24                   2.0  refs/heads/main
# 25                   1.0  refs/heads/main
# 26                   3.0  refs/heads/main
# 27                   1.0  refs/heads/main
# 28                   3.0  refs/heads/main
# 29                   2.0  refs/heads/main
#
#                                 payload.head  \
# 0   99fabd83ffd77cd098e973717f244df6ffcf2fa4
# 1   42bc28fa7f72541762967e4ddc4690f9287f0636
# 2   b823b92b558c7b770b2563079ea4afc74d609143
# 3   ae955f0cbac9b942add99503aaec3dc7dad9d984
# 4   fd35099aaa6bc1913262e6be3d91a61277d21b94
# 5   2f76f83df73eee6be05baaabb84c081ca730e035
# 6                                        NaN
# 7                                        NaN
# 8   e619ee64f1e856fde49a9a08fdd42bbb5fa29ba2
# 9   9539978b7817e03d31c703371cc6997cad1cd655
# 10  c7b6e8ff43c1dfd627015ccf2a142e9fffb3a742
# 11  166f9440cd99cca30e0e74e801117ec1e8e5212b
# 12  53ddaf4ed75f1529cdb3d306c1fdd360bc61dabc
# 13  9fc8541b6ced3154c100fbe525cc1dbea01da0e4
# 14  463b34b8432602ff105464fe013b4752bbb76001
# 15  1694031b81cf16017646a551df72b72f1e03fab7
# 16  d6e808384c9e4c5ddae5b78c43cf087feab18947
# 17  9acbac7618a9b62ef26352b0404f86dd6cfc018c
# 18  7656ac05c765f31e2d5ff670108afa308e9e6fcf
# 19  8dd721ffab7e7ebbf8233150e9c53c81e32d3b41
# 20  d8bd84df3c7dbd4434c74e65c85bb8312cc75e43
# 21  f8623ec490eca5ba683f16433f7eebba827c34c7
# 22  fd06d4d588f1e3203a209f0700a7e1c91f1b79a7
# 23  95ae7a92c52bb2f33ae0944b4a7b323458dbf307
# 24  15e639672201bb3401cacd681d7325f0cee81171
# 25  2d03291c42ac8eabdb479ba9277f2cc41335dfb3
# 26  c7acb872835aea6b7c67322c72dfcbdeafe61a5d
# 27  d153029ca1a5aa63b0dc53850e9096bd1d0afe67
# 28  b9dc9c85f669ab3d97a3afe95dec3904a2a17376
# 29  cca213e2f4027b221d4ea8caf7d0385624222d28
#
#                               payload.before  \
# 0   42bc28fa7f72541762967e4ddc4690f9287f0636
# 1   b823b92b558c7b770b2563079ea4afc74d609143
# 2   ae955f0cbac9b942add99503aaec3dc7dad9d984
# 3   668dab8ced38c4c28424b498d443600634a73610
# 4   c5e207df710d3b445b48df4757608fc6d04af00c
# 5   f218bffa51c9321d66403a4a4d33f76ae2fcd98d
# 6                                        NaN
# 7                                        NaN
# 8   9539978b7817e03d31c703371cc6997cad1cd655
# 9   c7b6e8ff43c1dfd627015ccf2a142e9fffb3a742
# 10  166f9440cd99cca30e0e74e801117ec1e8e5212b
# 11  53ddaf4ed75f1529cdb3d306c1fdd360bc61dabc
# 12  9fc8541b6ced3154c100fbe525cc1dbea01da0e4
# 13  463b34b8432602ff105464fe013b4752bbb76001
# 14  1694031b81cf16017646a551df72b72f1e03fab7
# 15  d6e808384c9e4c5ddae5b78c43cf087feab18947
# 16  9acbac7618a9b62ef26352b0404f86dd6cfc018c
# 17  7656ac05c765f31e2d5ff670108afa308e9e6fcf
# 18  8dd721ffab7e7ebbf8233150e9c53c81e32d3b41
# 19  d8bd84df3c7dbd4434c74e65c85bb8312cc75e43
# 20  f8623ec490eca5ba683f16433f7eebba827c34c7
# 21  fd06d4d588f1e3203a209f0700a7e1c91f1b79a7
# 22  95ae7a92c52bb2f33ae0944b4a7b323458dbf307
# 23  15e639672201bb3401cacd681d7325f0cee81171
# 24  2d03291c42ac8eabdb479ba9277f2cc41335dfb3
# 25  c7acb872835aea6b7c67322c72dfcbdeafe61a5d
# 26  d153029ca1a5aa63b0dc53850e9096bd1d0afe67
# 27  b9dc9c85f669ab3d97a3afe95dec3904a2a17376
# 28  cca213e2f4027b221d4ea8caf7d0385624222d28
# 29  b57002379d6ef15738ac14271c39b9432e502f0f
#
#                                       payload.commits payload.action  \
# 0   [{'sha': 'c9155dad815df5fc073bf231615f9ee6f7ea...            NaN
# 1   [{'sha': '42bc28fa7f72541762967e4ddc4690f9287f...            NaN
# 2   [{'sha': 'b823b92b558c7b770b2563079ea4afc74d60...            NaN
# 3   [{'sha': 'ae955f0cbac9b942add99503aaec3dc7dad9...            NaN
# 4   [{'sha': 'ea807f74bbd67bb865856e837b960bc9f5c5...            NaN
# 5   [{'sha': 'd153029ca1a5aa63b0dc53850e9096bd1d0a...            NaN
# 6                                                 NaN         closed
# 7                                                 NaN         opened
# 8   [{'sha': 'f218bffa51c9321d66403a4a4d33f76ae2fc...            NaN
# 9   [{'sha': '9539978b7817e03d31c703371cc6997cad1c...            NaN
# 10  [{'sha': '47017fc3970a454c841f5d23457f4296102f...            NaN
# 11  [{'sha': '166f9440cd99cca30e0e74e801117ec1e8e5...            NaN
# 12  [{'sha': '8917899ac9e7b86583c07ec6e63cef6869c5...            NaN
# 13  [{'sha': '9fc8541b6ced3154c100fbe525cc1dbea01d...            NaN
# 14  [{'sha': '463b34b8432602ff105464fe013b4752bbb7...            NaN
# 15  [{'sha': '1694031b81cf16017646a551df72b72f1e03...            NaN
# 16  [{'sha': 'd6e808384c9e4c5ddae5b78c43cf087feab1...            NaN
# 17  [{'sha': '9acbac7618a9b62ef26352b0404f86dd6cfc...            NaN
# 18  [{'sha': '7656ac05c765f31e2d5ff670108afa308e9e...            NaN
# 19  [{'sha': '547cace593e828f4ffb2496094003b023477...            NaN
# 20  [{'sha': 'd8bd84df3c7dbd4434c74e65c85bb8312cc7...            NaN
# 21  [{'sha': 'f8623ec490eca5ba683f16433f7eebba827c...            NaN
# 22  [{'sha': 'f992ee6355bb940b46427cb8d3175e4e9eb9...            NaN
# 23  [{'sha': '95ae7a92c52bb2f33ae0944b4a7b323458db...            NaN
# 24  [{'sha': 'da084ce5e39b86929bedf7b4c0607cc62b56...            NaN
# 25  [{'sha': '2d03291c42ac8eabdb479ba9277f2cc41335...            NaN
# 26  [{'sha': '69f85dd36a9bd3a53548d87abfd64492d4d5...            NaN
# 27  [{'sha': 'd153029ca1a5aa63b0dc53850e9096bd1d0a...            NaN
# 28  [{'sha': '87f2ab96bb2f752e81a5451ed9634596bcee...            NaN
# 29  [{'sha': '7903926b6149ffe76c62df5dce27818b649a...            NaN
#
#    payload.number                           payload.pull_request.url  \
# 0             NaN                                                NaN
# 1             NaN                                                NaN
# 2             NaN                                                NaN
# 3             NaN                                                NaN
# 4             NaN                                                NaN
# 5             NaN                                                NaN
# 6             2.0  https://api.github.com/repos/federicariva/Midb...
# 7             2.0  https://api.github.com/repos/federicariva/Midb...
# 8             NaN                                                NaN
# 9             NaN                                                NaN
# 10            NaN                                                NaN
# 11            NaN                                                NaN
# 12            NaN                                                NaN
# 13            NaN                                                NaN
# 14            NaN                                                NaN
# 15            NaN                                                NaN
# 16            NaN                                                NaN
# 17            NaN                                                NaN
# 18            NaN                                                NaN
# 19            NaN                                                NaN
# 20            NaN                                                NaN
# 21            NaN                                                NaN
# 22            NaN                                                NaN
# 23            NaN                                                NaN
# 24            NaN                                                NaN
# 25            NaN                                                NaN
# 26            NaN                                                NaN
# 27            NaN                                                NaN
# 28            NaN                                                NaN
# 29            NaN                                                NaN
#
#    payload.pull_request.id payload.pull_request.node_id
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN
# 5                      NaN                          NaN
# 6              935149830.0          PR_kwDOHTgHLs43vUEG
# 7              935149830.0          PR_kwDOHTgHLs43vUEG
# 8                      NaN                          NaN
# 9                      NaN                          NaN
# 10                     NaN                          NaN
# 11                     NaN                          NaN
# 12                     NaN                          NaN
# 13                     NaN                          NaN
# 14                     NaN                          NaN
# 15                     NaN                          NaN
# 16                     NaN                          NaN
# 17                     NaN                          NaN
# 18                     NaN                          NaN
# 19                     NaN                          NaN
# 20                     NaN                          NaN
# 21                     NaN                          NaN
# 22                     NaN                          NaN
# 23                     NaN                          NaN
# 24                     NaN                          NaN
# 25                     NaN                          NaN
# 26                     NaN                          NaN
# 27                     NaN                          NaN
# 28                     NaN                          NaN
# 29                     NaN                          NaN
#
# [30 rows x 24 columns]

# %% [markdown]
# # 3. random pointless API´s

# %%
response=requests.get('https://api.agify.io?name=Cath')

# %%
response.content
# Out:
# b'{"name":"Cath","age":64,"count":3019}'

# %%
response=requests.get('https://api.nationalize.io?name=Cath')

# %%
response.content
# Out:
# b'{"name":"Cath","country":[{"country_id":"BE","probability":0.2626993811235692},{"country_id":"FR","probability":0.20262496075071343},{"country_id":"GB","probability":0.20138737541270862}]}'

# %%
# what should I d when I´m bored
response=requests.get('https://www.boredapi.com/api/activity')

# %%
response.content
# Out:
# b'{"activity":"Watch a movie you\'d never usually watch","type":"relaxation","participants":1,"price":0.15,"link":"","key":"9212950","accessibility":0.15}'
