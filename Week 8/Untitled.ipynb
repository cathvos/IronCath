# %% [markdown]
# # Lab day 3

# %% [markdown]
# #### https://venturebeat.com/2022/05/04/gaming-has-the-opportunity-to-re-invent-itself-beyond-gamergate-with-web3-heres-how/

# %% [markdown]
# # Giraffe by tree
# ## A giraffe hanging out with a monkey

# %%
# %matplotlib inline
from IPython.display import Image
Image('computer vision explorer.png')

# %% [markdown]
# ### I´m not super impressed by the picture negerated, don´t get why it´s so blurry and you don´t clearly see the animals. You can see a monkey, giraffes and trees so it did do it´s job.

# %% [markdown]
# # Image Recognition: Dogs vs Cats! (92%)

# %% [markdown]
# Basically he explains how to build and tune a convolutional network with keras for image classification,
# how to choose the right optimizer to make sure that your network is able to learn and how to
# use the keras ImageDataGenerator to augment your dataset and limit overfitting
