# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
# %matplotlib inline 
sns.set(rc={"figure.figsize":(12.,6.)})
sns.set_style("whitegrid")
import warnings
warnings.filterwarnings('ignore')
df_train=pd.read_excel('cookies_comp_students.xlsx')
df_test =pd.read_csv ('cookies_comp_studentstest.csv')

# %%
df_train
# Out:
#       sugar to flour ratio  sugar index  bake temp  chill time  calories  \
# 0                     0.25          9.5        300        15.0     136.0
# 1                     0.23          3.3        520        34.0     113.0
# 2                     0.18          1.9        360        33.0     106.0
# 3                     0.18         10.5        490        41.0     124.0
# 4                     0.24          2.4        770         6.0      33.0
# ...                    ...          ...        ...         ...       ...
# 5193                  0.66          2.0        390        15.0      88.0
# 5194                  0.16          1.5        490        10.0      97.0
# 5195                  0.25         14.3        480        79.0     149.0
# 5196                  0.33          1.4        560        35.0     136.0
# 5197                  0.44          1.8        810        28.0      68.0
#
#       density    pH  grams baking soda  bake time  quality butter type  \
# ...

# %%
df_train['diameter'].values
# Out:
# array([7, 7, 7, ..., 7, 7, 7])

# %%
df_test.info
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 df_test.info
#
# AttributeError: 'NoneType' object has no attribute 'info'

# %%
df_train.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5169 entries, 0 to 5168
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   sugar to flour ratio  5169 non-null   float64
#  1   sugar index           5169 non-null   float64
#  2   bake temp             5169 non-null   int64
#  3   chill time            5169 non-null   float64
#  4   calories              5169 non-null   float64
#  5   density               5169 non-null   float64
#  6   pH                    5169 non-null   float64
#  7   grams baking soda     5169 non-null   float64
#  8   bake time             5169 non-null   float64
#  9   quality               5169 non-null   int64
#  10  butter type           5169 non-null   object
#  11  weight                5169 non-null   float64
#  12  diameter              5169 non-null   int64
#  13  mixins                5169 non-null   object
# ...

# %%
df_train=df_train.dropna() # drop nulls

# %%
df_train
# Out:
#       sugar to flour ratio  sugar index  bake temp  chill time  calories  \
# 0                     0.25          9.5        300        15.0     136.0
# 1                     0.23          3.3        520        34.0     113.0
# 2                     0.18          1.9        360        33.0     106.0
# 3                     0.18         10.5        490        41.0     124.0
# 4                     0.24          2.4        770         6.0      33.0
# ...                    ...          ...        ...         ...       ...
# 5193                  0.66          2.0        390        15.0      88.0
# 5194                  0.16          1.5        490        10.0      97.0
# 5195                  0.25         14.3        480        79.0     149.0
# 5196                  0.33          1.4        560        35.0     136.0
# 5197                  0.44          1.8        810        28.0      68.0
#
#       density    pH  grams baking soda  bake time  quality butter type  \
# ...

# %%
df_train.duplicated().sum() # count duplicates
# Out:
# 12

# %%
df_train[df_train.duplicated(keep=False)] # see duplicates
# Out:
#       sugar to flour ratio  sugar index  bake temp  chill time  calories  \
# 34                    0.36         13.2        670        53.0     178.0
# 147                   0.30         12.8        620        19.0     171.0
# 1143                  0.29         10.5        400        21.0     145.0
# 1429                  0.43          1.6        350        31.0     128.0
# 1600                  0.00          1.8        500        27.0      63.0
# 1850                  0.32          3.6        350        22.0      93.0
# 2024                  0.35         15.3        560        31.0     117.0
# 3022                  0.30          1.6        450        36.0     139.0
# 3076                  0.35         13.5        380        49.0     118.0
# 3115                  0.13          4.5        390        17.0     116.0
# 3259                  0.29         10.5        400        21.0     145.0
# 3294                  0.45          8.3        500        52.0     196.0
# ...

# %%
df_train=df_train.drop_duplicates()# drop duplicate and replaces the data frame

# %%
df_train.reset_index(drop=True, inplace=True) # resetting index after dropping duplicates

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5169 entries, 0 to 5168
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   sugar to flour ratio  5169 non-null   float64
#  1   sugar index           5169 non-null   float64
#  2   bake temp             5169 non-null   int64
#  3   chill time            5169 non-null   float64
#  4   calories              5169 non-null   float64
#  5   density               5169 non-null   float64
#  6   pH                    5169 non-null   float64
#  7   grams baking soda     5169 non-null   float64
#  8   bake time             5169 non-null   float64
#  9   quality               5169 non-null   int64
#  10  butter type           5169 non-null   object
#  11  weight                5169 non-null   float64
#  12  diameter              5169 non-null   int64
#  13  mixins                5169 non-null   object
# ...

# %%
df_train_num=df.drop(columns=['butter type', 'mixins'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 df_train_num=df.drop(columns=['butter type', 'mixins'])
#
# NameError: name 'df' is not defined
