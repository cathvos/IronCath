# %%
import pandas as pd

# %%
df=pd.read_csv('alldata.csv')

# %%
df.head(5)
# Out:
#                                             position             company  \
# 0                               Development Director             ALS TDI
# 1  An Ostentatiously-Excitable Principal Research...  The Hexagon Lavish
# 2                                     Data Scientist      Xpert Staffing
# 3                                       Data Analyst      Operation HOPE
# 4  Assistant Professor -TT - Signal Processing & ...    Emory University
#
#                                          description  reviews  \
# 0  Development Director\nALS Therapy Development ...      NaN
# 1  Job Description\n\n"The road that leads to acc...      NaN
# 2  Growing company located in the Atlanta, GA are...      NaN
# 3  DEPARTMENT: Program OperationsPOSITION LOCATIO...     44.0
# 4  DESCRIPTION\nThe Emory University Department o...    550.0
#
#              location
# 0  Atlanta, GA 30301
# 1         Atlanta, GA
# 2         Atlanta, GA
# 3  Atlanta, GA 30303
# 4         Atlanta, GA

# %%
df.columns
# Out:
# Index(['position', 'company', 'description', 'reviews', 'location'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6964 entries, 0 to 6963
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   position     6953 non-null   object
#  1   company      6953 non-null   object
#  2   description  6953 non-null   object
#  3   reviews      5326 non-null   float64
#  4   location     6953 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 272.2+ KB

# %%
df['position'] = df['position'].str.lower() # set all to lower case

# %%
df['description'] = df['description'].str.lower() # set all to lower case

# %%
df.head(5)
# Out:
#                                             position             company  \
# 0                               development director             ALS TDI
# 1  an ostentatiously-excitable principal research...  The Hexagon Lavish
# 2                                     data scientist      Xpert Staffing
# 3                                       data analyst      Operation HOPE
# 4  assistant professor -tt - signal processing & ...    Emory University
#
#                                          description  reviews  \
# 0  development director\nals therapy development ...      NaN
# 1  job description\n\n"the road that leads to acc...      NaN
# 2  growing company located in the atlanta, ga are...      NaN
# 3  department: program operationsposition locatio...     44.0
# 4  description\nthe emory university department o...    550.0
#
#              location
# 0  Atlanta, GA 30301
# 1         Atlanta, GA
# 2         Atlanta, GA
# 3  Atlanta, GA 30303
# 4         Atlanta, GA

# %%
df[['city', 'state_postcode']] = df['location'].str.split(',', 1, expand=True)
df['state'] = df['state_postcode'].str.replace('\d+','', regex=True) #regex=True means the string is a regular expression, not a common string
# also works: df['state'] = df['state_postcode'].str.extract('([a-zA-Z ]+)', expand=False).str.strip()
df.drop(['location'], axis = 1, inplace = True)
df.drop(['state_postcode'], axis = 1, inplace = True)

# %%
df['city'].unique()
# Out:
# array(['Atlanta', 'Austin', 'Round Rock', 'Cedar Park', nan, 'Boulder',
#        'Boston', 'Chicago', 'Washington', 'Los Angeles', 'Cambridge',
#        'Mountain View', 'Manhattan', 'New York', 'Jersey City', 'Newark',
#        'Oakland', 'Bronx', 'Hoboken', 'Brooklyn', 'Rutherford', 'Union',
#        'Rahway', 'Murray Hill', 'South Plainfield', 'Queens',
#        'Little Falls', 'Florham Park', 'Troy Hills', 'Bloomfield',
#        'Lynbrook', 'Allendale', 'Parsippany', 'West Orange', 'Kenilworth',
#        'Ridgefield', 'Harrison', 'Montclair', 'Fort Lee', 'Carlstadt',
#        'Orangeburg', 'Fairfield', 'Palisades', 'Hackensack', 'Roseland',
#        'East Hanover', 'Long Beach', 'Whippany', 'Manhasset', 'Yonkers',
#        'New Hyde Park', 'Secaucus', 'Port Washington', 'Staten Island',
#        'Short Hills', 'Manhattanville', 'Woodcliff Lake', 'Redmond',
#        'San Diego', 'Bedminster', 'New Brunswick', 'Seattle',
# ...

# %%
df['state'].unique()
# Out:
# array([' GA  ', ' GA', ' GA ', ' TX', ' TX ', nan, ' CO', ' CO ', ' MA',
#        ' MA ', ' IL', ' IL ', ' DC ', ' DC', ' CA', ' CA ', ' NY', ' NY ',
#        ' NJ', ' NJ ', ' NY  ', ' NJ  ', ' WA ', ' WA'], dtype=object)

# %%
df['reviews'].unique()
# Out:
# array([        nan, 4.40000e+01, 5.50000e+02, 3.85000e+02, 8.99000e+02,
#        3.34300e+03, 4.49400e+03, 3.88440e+04, 3.90000e+02, 9.12000e+02,
#        1.04000e+02, 1.52000e+02, 7.22000e+02, 4.47000e+02, 4.96000e+02,
#        5.72000e+03, 7.80000e+01, 9.20000e+01, 9.59000e+02, 7.00000e+00,
#        3.55800e+03, 2.90000e+01, 3.50000e+02, 7.23600e+03, 2.96300e+03,
#        1.59000e+02, 3.18200e+03, 3.47000e+02, 2.19540e+04, 1.27000e+02,
#        1.40000e+02, 9.50000e+02, 2.60000e+02, 8.00000e+00, 1.18100e+03,
#        3.75000e+02, 2.60000e+01, 1.50000e+01, 2.59070e+04, 1.39000e+02,
#        2.57000e+02, 1.40000e+01, 2.06000e+02, 6.58000e+02, 6.12100e+03,
#        2.21000e+02, 1.44000e+02, 1.89000e+02, 1.42000e+04, 2.00000e+00,
#        1.00000e+01, 4.06100e+03, 1.68000e+02, 1.31000e+02, 2.10000e+01,
#        5.70000e+01, 8.38000e+02, 3.30000e+01, 1.30100e+03, 5.24000e+02,
#        2.22570e+04, 2.20000e+01, 5.90000e+01, 6.53000e+02, 3.92000e+02,
# ...

# %%
df_da=df[df['position'].str.contains('data analyst')==True]# creating a subset of data analyst positions

# %%
df_da2=df_da.assign(job_title="Data Analyst")
print(df_da2)
# Out:
#                                               position  \
# 3                                         data analyst
# 74                           data analyst supply chain
# 100            enterprise data analyst & data engineer
# 251                       sr data analyst supply chain
# 287      data analyst - public education data analysis
# ...                                                ...
# 6643                             research data analyst
# 6680                           healthcare data analyst
# 6707                          data analyst, s&p - jump
# 6785  lead data analyst - digital test and measurement
# 6937                     data scientist / data analyst
#
#                        company  \
# 3               Operation HOPE
# 74              The Home Depot
# 100                    Novelis
# 251             The Home Depot
# 287   Legislative Budget Board
# ...                        ...
# 6643                       JLL
# 6680                     Medal
# ...

# %%
df_da2
# Out:
#                                               position  \
# 3                                         data analyst
# 74                           data analyst supply chain
# 100            enterprise data analyst & data engineer
# 251                       sr data analyst supply chain
# 287      data analyst - public education data analysis
# ...                                                ...
# 6643                             research data analyst
# 6680                           healthcare data analyst
# 6707                          data analyst, s&p - jump
# 6785  lead data analyst - digital test and measurement
# 6937                     data scientist / data analyst
#
#                        company  \
# 3               Operation HOPE
# 74              The Home Depot
# 100                    Novelis
# 251             The Home Depot
# 287   Legislative Budget Board
# ...                        ...
# 6643                       JLL
# 6680                     Medal
# ...

# %%
df_ds=df[df['position'].str.contains('data scientist')==True] # creating a subset of data scientist positions

# %%
df_ds2=df_ds.assign(job_title="Data Scientist")
print(df_ds2)
# Out:
#                                                position         company  \
# 2                                        data scientist  Xpert Staffing
# 9     senior associate - cognitive data scientist na...            KPMG
# 12                     senior associate, data scientist            KPMG
# 15                                       data scientist        Cotiviti
# 18                                       data scientist     Relus Cloud
# ...                                                 ...             ...
# 6949  systems software performance data scientist su...         Alibaba
# 6951                          lead data scientist - nlp          TARGET
# 6957                      lead data scientist - haskell          TARGET
# 6958                   senior data scientist (gec11902)         Walmart
# 6963            principal data scientist, deep learning         Comcast
#
#                                             description   reviews       city  \
# ...

# %%
df_ds2
# Out:
#                                                position         company  \
# 2                                        data scientist  Xpert Staffing
# 9     senior associate - cognitive data scientist na...            KPMG
# 12                     senior associate, data scientist            KPMG
# 15                                       data scientist        Cotiviti
# 18                                       data scientist     Relus Cloud
# ...                                                 ...             ...
# 6949  systems software performance data scientist su...         Alibaba
# 6951                          lead data scientist - nlp          TARGET
# 6957                      lead data scientist - haskell          TARGET
# 6958                   senior data scientist (gec11902)         Walmart
# 6963            principal data scientist, deep learning         Comcast
#
#                                             description   reviews       city  \
# ...

# %%
df_eng=df[df['position'].str.contains('engineer')==True] # creating a subset of engineer positions

# %%
df_eng2=df_eng.assign(job_title="Engineer")
print(df_eng2)
# Out:
#                                                position             company  \
# 5                           manager of data engineering  McKinsey & Company
# 7     junior to mid-level engineer, geologist or env...                Wood
# 16    senior structural engineer-transmission & dist...   Burns & McDonnell
# 20                           senior electrical engineer   Burns & McDonnell
# 61                                        data engineer              Gallup
# ...                                                 ...                 ...
# 6908                senior software engineer - back end   Walmart eCommerce
# 6912  senior platform software engineer - fixed netw...               NOKIA
# 6915  senior/staff full stack engineer - advertising...   Walmart eCommerce
# 6941  data scientist, engineering support analytics,...              Google
# 6955                                      data engineer          Amazon.com
#
# ...

# %%
df_eng2
# Out:
#                                                position             company  \
# 5                           manager of data engineering  McKinsey & Company
# 7     junior to mid-level engineer, geologist or env...                Wood
# 16    senior structural engineer-transmission & dist...   Burns & McDonnell
# 20                           senior electrical engineer   Burns & McDonnell
# 61                                        data engineer              Gallup
# ...                                                 ...                 ...
# 6908                senior software engineer - back end   Walmart eCommerce
# 6912  senior platform software engineer - fixed netw...               NOKIA
# 6915  senior/staff full stack engineer - advertising...   Walmart eCommerce
# 6941  data scientist, engineering support analytics,...              Google
# 6955                                      data engineer          Amazon.com
#
# ...

# %%
df_pos=pd.concat([df_da2, df_ds2, df_eng2]) # putting the 3 sets together to get 1 set with the 3 positions only

# %%
df_pos
# Out:
#                                                position  \
# 3                                          data analyst
# 74                            data analyst supply chain
# 100             enterprise data analyst & data engineer
# 251                        sr data analyst supply chain
# 287       data analyst - public education data analysis
# ...                                                 ...
# 6908                senior software engineer - back end
# 6912  senior platform software engineer - fixed netw...
# 6915  senior/staff full stack engineer - advertising...
# 6941  data scientist, engineering support analytics,...
# 6955                                      data engineer
#
#                        company  \
# 3               Operation HOPE
# 74              The Home Depot
# 100                    Novelis
# 251             The Home Depot
# 287   Legislative Budget Board
# ...                        ...
# 6908         Walmart eCommerce
# ...

# %%
df_pos[df_pos['description'].str.contains('master')==True]
# Out:
#                                                position  \
# 333                           quantitative data analyst
# 362                compliance quantitative data analyst
# 765   research data analyst, school of public health...
# 1363                                       data analyst
# 1424                              research data analyst
# ...                                                 ...
# 6875              senior software engineer - full stack
# 6883                        principal software engineer
# 6894                         senior quality engineer qa
# 6902                          senior front end engineer
# 6955                                      data engineer
#
#                                         company  \
# 333   Pacific Investment Management Company LLC
# 362                                        TSYS
# 765                           Boston University
# 1363                                 TrueMotion
# ...

# %%
df_pos[df_pos['description'].str.contains('bachelor')==True]
# Out:
#                                                position  \
# 3                                          data analyst
# 74                            data analyst supply chain
# 100             enterprise data analyst & data engineer
# 251                        sr data analyst supply chain
# 298                                        data analyst
# ...                                                 ...
# 6892                         senior it quality engineer
# 6894                         senior quality engineer qa
# 6895                senior systems integration engineer
# 6902                          senior front end engineer
# 6915  senior/staff full stack engineer - advertising...
#
#                                company  \
# 3                       Operation HOPE
# 74                      The Home Depot
# 100                            Novelis
# 251                     The Home Depot
# 298               Applied Systems Inc.
# ...                                ...
# ...

# %%
df_pos[df_pos['description'].str.contains('phd')==True]
# Out:
#                                                position  \
# 2517                                   rwe data analyst
# 2570                               rwe sr. data analyst
# 3194                              business data analyst
# 4131  data analyst, bureau of hiv/aids prevention an...
# 4282                                       data analyst
# ...                                                 ...
# 6898                 paranoids sr software dev engineer
# 6903                           sr software dev engineer
# 6904                    principal software dev engineer
# 6908                senior software engineer - back end
# 6941  data scientist, engineering support analytics,...
#
#                             company  \
# 2517                         Sanofi
# 2570                         Sanofi
# 3194                         Intuit
# 4131  DEPT OF HEALTH/MENTAL HYGIENE
# 4282                      Schireson
# ...                             ...
# ...

# %%
df_pos
# Out:
#                                                position  \
# 3                                          data analyst
# 74                            data analyst supply chain
# 100             enterprise data analyst & data engineer
# 251                        sr data analyst supply chain
# 287       data analyst - public education data analysis
# ...                                                 ...
# 6908                senior software engineer - back end
# 6912  senior platform software engineer - fixed netw...
# 6915  senior/staff full stack engineer - advertising...
# 6941  data scientist, engineering support analytics,...
# 6955                                      data engineer
#
#                        company  \
# 3               Operation HOPE
# 74              The Home Depot
# 100                    Novelis
# 251             The Home Depot
# 287   Legislative Budget Board
# ...                        ...
# 6908         Walmart eCommerce
# ...

# %%
df_pos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2746 entries, 3 to 6955
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   position     2746 non-null   object
#  1   company      2746 non-null   object
#  2   description  2746 non-null   object
#  3   reviews      2001 non-null   float64
#  4   city         2746 non-null   object
#  5   state        2746 non-null   object
#  6   job_title    2746 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 171.6+ KB

# %%
df_pos.to_csv('df_pos.csv', index=False)

# %%
pwd
# Out:
# '/Users/cathalijnvos/Documents/GitHub/IronCath/IH week 2/project week 2'

# %%
def sql(description):
    if 'sql' in description:
        return True
    else:
         return False
df_pos['sql']=df_pos['description'].apply(sql)

def python(description):
    if 'python' in description:
        return True
    else:
         return False
df_pos['python']=df_pos['description'].apply(python)

def excel(description):
    if 'excel' in description:
        return True
    else:
         return False
df_pos['excel']=df_pos['description'].apply(excel)

def tableau(description):
    if 'sql' in description:
        return True
    else:
         return False
df_pos['sql']=df_pos['description'].apply(tableau)

# %%
df_pos
# Out:
#                                                position  \
# 3                                          data analyst
# 74                            data analyst supply chain
# 100             enterprise data analyst & data engineer
# 251                        sr data analyst supply chain
# 287       data analyst - public education data analysis
# ...                                                 ...
# 6908                senior software engineer - back end
# 6912  senior platform software engineer - fixed netw...
# 6915  senior/staff full stack engineer - advertising...
# 6941  data scientist, engineering support analytics,...
# 6955                                      data engineer
#
#                        company  \
# 3               Operation HOPE
# 74              The Home Depot
# 100                    Novelis
# 251             The Home Depot
# 287   Legislative Budget Board
# ...                        ...
# 6908         Walmart eCommerce
# ...

# %%
df_pos['sql'] = df_pos['sql'].astype(int)
df_pos['tableau'] = df_pos['tableau'].astype(int)
df_pos['python'] = df_pos['python'].astype(int)
df_pos['excel'] = df_pos['excel'].astype(int)

# %%
df_pos
# Out:
#                                                position  \
# 3                                          data analyst
# 74                            data analyst supply chain
# 100             enterprise data analyst & data engineer
# 251                        sr data analyst supply chain
# 287       data analyst - public education data analysis
# ...                                                 ...
# 6908                senior software engineer - back end
# 6912  senior platform software engineer - fixed netw...
# 6915  senior/staff full stack engineer - advertising...
# 6941  data scientist, engineering support analytics,...
# 6955                                      data engineer
#
#                        company  \
# 3               Operation HOPE
# 74              The Home Depot
# 100                    Novelis
# 251             The Home Depot
# 287   Legislative Budget Board
# ...                        ...
# 6908         Walmart eCommerce
# ...

# %%
df_pos.to_csv('df_pos_final.csv', index=False)
